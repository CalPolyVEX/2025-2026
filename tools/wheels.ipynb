# %%
def avg(vals: list[float]) -> float:
    if len(vals) == 0:
        return 1.0
    return sum(vals) / len(vals)

# %%
# GOLD BOT


hori = 2.0
vert = 2.0

valsH = [
    95.931,
    95.67,
    95.92,
    95.78,
    95.86
    

    
]

valsV = [
    94.9256,
    95.282,
    95.1441,
    #96.02,
    95.34,
    95.9
    #96.24,
]

print(f"Test avg for valsV: {sum(valsV) / len(valsV)} == {avg(valsV)} ?")

print(f"Hori: {96.0 / avg(valsH) * 2.0}, Vert: {96.0 / avg(valsV) * 2.0}")
# Out:
# Test avg for valsV: 95.31834 == 95.31834 ?
# Hori: 2.0035019544578963, Vert: 2.01430280888232

# %%
# GREEN BOT


hori = 2.0
vert = 2.0

valsH = [
    

    
]

valsV = [

]

print(f"Test avg for valsV: {sum(valsV) / len(valsV)} == {avg(valsV)} ?")

print(f"Hori: {96.0/ avg(valsH) * 2.0}, Vert: {96.0 / avg(valsV) * 2.0}")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[36], line 17
#       7 valsH = [
#       8
#       9
#      10
#      11 ]
#      13 valsV = [
#      14
#      15 ]
# ---> 17 print(f"Test avg for valsV: {sum(valsV) / len(valsV)} == {avg(valsV)} ?")
#      19 print(f"Hori: {96.0/ avg(valsH) * 2.0}, Vert: {96.0 / avg(valsV) * 2.0}")
#
# ZeroDivisionError: division by zero
